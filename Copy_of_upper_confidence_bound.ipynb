# %% [markdown]
# <a href="https://colab.research.google.com/github/Sona30k/ML/blob/main/Copy_of_upper_confidence_bound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Upper Confidence Bound (UCB)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Ads_CTR_Optimisation.csv")

# %% [markdown]
# ## Implementing UCB

# %%
import math
N=10000
d=10
ads=[]
selection = [0]* d
rewards =[0]*d
total = 0
for n in range(0,N):
  ad = 0
  max_upper_bound =0
  for i in range(0,d):
    if selection[i]>0:
      avg_reward =rewards[i]/selection[i]
      delta= math.sqrt(3/2*math.log(n+1)/selection[i])
      upper_bound = avg_reward+ delta
    else:

      upper_bound = 1e400
    if( upper_bound>max_upper_bound):
      max_upper_bound = upper_bound
      ad =i
    ads.append(ad)
    selection[ad] = selection[ad]+1
    rewardzz = dataset.values[n,ad]
    rewards[ad]= rewards[ad]+ rewardzz
    total=total+rewardzz

# %% [markdown]
# ## Visualising the results

# %%
plt.hist(ads)
plt.title("histogram of ADS")
plt.xlabel("ads")
plt.ylabel("number of time each ad was selected")
plt.show()
