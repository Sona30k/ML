# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
regress = LinearRegression()
regress.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
reg_ploy = PolynomialFeatures(degree = 4) #change the degress according
x_poly = reg_ploy.fit_transform(x)
regress_2 = LinearRegression()
regress_2.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x ,y, color ='grey')
plt.plot(x, regress.predict(x), color ='purple')
plt.title('Truth or bluff(Linear Regression)')
plt.xlabel('position')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x ,y, color ='grey')
plt.plot(x, regress_2.predict(x_poly), color ='purple')
plt.title('Truth or bluff(POlynomial Regression)')
plt.xlabel('position')
plt.ylabel('salary')
plt.show()
#prefect prediction as degree is 4

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
x_grid = np.arange(min(x), max(x),0.1)
x_grid = x_grid.reshape((len(x_grid),1))
plt.scatter(x ,y, color ='orange')
plt.plot(x_grid, regress_2.predict(reg_ploy.fit_transform(x_grid)), color ='blue')
plt.title('Truth or bluff(POlynomial Regression)')
plt.xlabel('position')
plt.ylabel('salary')
plt.show()
# Out:
# <ipython-input-23-85aa1ba53622>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x),0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
regress.predict([[6.5]]) # to create 2 d array pair of sq bracktes are used
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
regress_2.predict(reg_ploy.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
